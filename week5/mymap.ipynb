# %% [markdown]
# my map

# %%
# import folium, a leaflet python library
import folium

# create a list of lat/lon pair for UCLA
reitaku = [35.8330, 139.9550]
Smokingarea1 =[35.83452053659138, 139.9551473034779]
Smokingarea2=[35.83168020569613, 139.9557246212256]
konbini_Smokingarea=[35.83151276076011, 139.9561893208628]
minamikashiwa=[35.84457026358922, 139.95408959248516]
shinkashiwa=[35.83808559993648, 139.96707812186202]

# make the map
where_i_appear = folium.Map(location=reitaku, zoom_start=15)

# add a marker
folium.Marker(reitaku, popup="Reitaku University, the best place on earth!", tooltip="Reitaku University").add_to(where_i_appear)
folium.Marker(Smokingarea1, popup="Reitaku University Smokingarea1, the best place on earth!", tooltip="Reitaku University Smokingarea1").add_to(where_i_appear)
folium.Marker(Smokingarea1, popup="Reitaku University Smokingarea2, the best place on earth!", tooltip="Reitaku University Smokingarea2").add_to(where_i_appear)
folium.Marker(konbini_Smokingarea, popup="konbini & Smokingarea, the best place on earth!", tooltip="konbini & Smokingarea").add_to(where_i_appear)
folium.Marker(minamikashiwa, popup="minamikasiwa, the best place on earth!", tooltip="minamikashiwa").add_to(where_i_appear)
folium.Marker(shinkashiwa, popup="shinkashiwa, the best place on earth!", tooltip="shinkashiwa").add_to(where_i_appear)

# show the map
where_i_appear
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
